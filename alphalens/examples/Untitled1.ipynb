# %%
# %matplotlib inline

# %%
import plotly
plotly.offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import plotly.graph_objects as go
import plotly.figure_factory as ff

import numpy as np
import pandas as pd
import scipy

# %%
import numpy as np
import statsmodels.api as sm
import pylab

test = np.random.normal(0,1, 1000)

sm.qqplot(test, line='45')
# pylab.show()

# %%
from statsmodels.graphics.gofplots import qqplot

qqplot_data = qqplot(gauss_data, line='45').gca().lines

# %%
x = np.random.normal(loc=8.5, scale=2.5, size=37)

# %%
import statsmodels.api as sm

# %%
pp_x = sm.ProbPlot(x)

# %%
pp_x.sample_quantiles
# Out:
# array([ 3.73135778,  4.45357313,  5.19888114,  5.43541005,  5.67612201,
#         6.19272684,  6.53182768,  6.65160815,  6.90009349,  7.0672166 ,
#         7.32298187,  7.40243441,  7.49965412,  7.6277952 ,  7.71792811,
#         7.76004037,  7.92513339,  7.94551716,  8.13908309,  8.79368915,
#         8.85276042,  8.91702567,  9.1826233 ,  9.23235181,  9.2845763 ,
#         9.36558279,  9.67437859, 10.16972402, 10.26707614, 10.62052152,
#        11.05629027, 11.59051332, 11.84981577, 11.95808057, 12.64179156,
#        14.51081401, 14.66331271])

# %%
pp_x.theoretical_quantiles
# Out:
# array([-1.93793151, -1.61985626, -1.41218758, -1.25211952, -1.11895838,
#        -1.00314797, -0.89943491, -0.80459638, -0.7164975 , -0.63364   ,
#        -0.55492294, -0.47950565, -0.40672425, -0.33603814, -0.26699413,
#        -0.19920132, -0.13231285, -0.06601181,  0.        ,  0.06601181,
#         0.13231285,  0.19920132,  0.26699413,  0.33603814,  0.40672425,
#         0.47950565,  0.55492294,  0.63364   ,  0.7164975 ,  0.80459638,
#         0.89943491,  1.00314797,  1.11895838,  1.25211952,  1.41218758,
#         1.61985626,  1.93793151])
